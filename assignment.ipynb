# %% [raw]
# Q1.Explain the key feature of python that make it a popular choice for programming
#  There are so many features in python that make it a popular language for programming.
#           * Python is easy to code as compare to the the other programming language like java,c and c++.
#           * Python is easy to learn and read also beacause of it's simple and straightforward syntax.
#           * PYthon has very huge number's of standard libraries around 1.3 lakhs.
#           * Python is a very versatile language So that it can be use in various works like frontend,backend,machine learning and many more.
#           * Python is a open source programming language and it is free so anyone can use and due to open source anyone can contribute in this language.
#           * Python has very large community support as it becomes very popular programming language.
#           * Easy to debug
#           * Python is a portable programming language.we can run the same code with very few changes on any operating system like window,mac and linux etc.
#           * Python also support GUI (Graphical User Interface) so we can make GUI with the use of python modeule like PyQt5.
#           * Python is a dynamically typed programming language So we not need to specifie variables while writting the code.
#           * It is a high level programming language.

# %% [raw]
# Q2.Describe the role of predefined keywords in python and provide examples how they are use in program.
#   * Predefined keywords in python - It is reserved word in python that can not be use as identifier,variable or     function.Predefined keywords have spacial meaning in python.Most of the keywords are use in lower case b         except True and False.
#                          Example of predefined keywords in python.

# %%
help('keyword')
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "Grammar/python.gram")
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/keyword.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree and run:
#
#         PYTHONPATH=Tools/peg_generator python3 -m pegen.keywordgen         Grammar/python.gram         Grammar/Tokens         Lib/keyword.py
#
#     Alternatively, you can run 'make regen-keyword'.
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
#         x.__contains__(y) <==> y in x.
#
#     issoftkeyword = __contains__(...) method of builtins.frozenset instance
#         x.__contains__(y) <==> y in x.
#
# DATA
#     __all__ = ['iskeyword', 'issoftkeyword', 'kwlist', 'softkwlist']
#     kwlist = ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'aw...
#     softkwlist = ['_', 'case', 'match']
#
# FILE
#     /opt/conda/lib/python3.10/keyword.py

# %%
#ex1
a = 5
if a>4:
    #if is a predefined keyword which is use to give condition in program
    print("larger no")
elif a<4:
    print("smaller no")
    #else and elif is also a predefined keyword in conditional statement
else:
    print("not a number")
# Out:
# larger no

# %%
a = 5
type(a)
# Out:
# float

# %%
b = 9.4
#it is also a predefined keywords
type(b)
# Out:
# float

# %%
name = "amit"
#it is also a predefined keywords
type(name)
# Out:
# str

# %% [raw]
# Q3.Compare and contrast mutable and immutable object in the python with example.
#     DEFINATION-Mutable object are those object in python that can be change after the creation and also it can       be replace by other object.
#     some mutable object are list,dictionarie and set etc.
#     DEFINATION-Immutable object are those object are those object that can not be change after creation and also     it can not be replace by other object.
#     some immutable object are integers, tuples, and string.

# %%
#example of mutable object.
mtb = [1, 1.2, 'amit', a, bool, 5+4j]
print(mtb)
# Out:
# [1, 1.2, 'amit', 5, <class 'bool'>, (5+4j)]

# %%
type(mtb)
#type of container.
# Out:
# list

# %%
mtb[1] = 105
#replacing the data from container.

# %%
print(mtb)
# Out:
# [1, 105, 'amit', 5, <class 'bool'>, (5+4j)]

# %%
#example of immutable object
my_string = "amit_kumar"
print(my_string)
#output-amit_kumar
type(my_string)
#output-str
# Out:
# amit_kumar
# str

# %%
my_string[0]
# Out:
# 'a'

# %%
my_string[0] = "s"
#here we are getting an error that str object does not support assignment.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 my_string[0] = "s"
#       2 #here we are getting an error that str object does not support assignment.
#
# TypeError: 'str' object does not support item assignment

# %%
print(my_string)
# Out:
# amit_kumar

# %% [raw]
# DIFFERENCES BETWEEN MUTABLE AND IMUTTABLE OBJECT.
# * Modifiability- Mutable object can be modify after creation but immutable object can not be modify after         creation.
# * Identity: Mutable objects can change their internal state, while immutable objects retain their original         state.
# * Assignment: When you assign a new value to a mutable object, you are modifying the original object. When you     assign a new value to an immutable object, you are creating a new object.

# %% [raw]
# Q4.Discuss the different types of operator in python and provide examples how they are used.
#    Operator in python are the spacial symbol or keywords which are use to python to menipulate the data through    various opeartions like arithmetic calculations, logical evaluations, bitwise manipulations, etc.

# %%
#Example of arthematic opeartion.
num1=int(input("Enter a number:"))
num2=int(input("Enter one more number:"))
print(num1 + num2) #addition of number
print(num1 - num2) #subtraction of number
print(num1 * num2) #multiply of number
print(num1 / num2) #division of number
print(num1 // num2) #floor division of number
print(num1 % num2) #modulus of number
print(num1 ** num2) #exponent of number
# Out:
# Enter a number: 5
# Enter one more number: 3
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 2
# 125

# %%
#Example of bitwise operator
a = 5
b = 4
c = a & b
print("a & b",c) #addition of number
c = a|b
print("a | b",c) #OR of number
print(~a) #negation
print(5<<3) #left shift operator
print(5>>3) #right operator
# Out:
# a & b 4
# a | b 5
# -6
# 40
# 0

# %%
#example of assignment operator.
a = 10
# Addition Assignment
a += 5
print ("a += 5 : ", a)
# Subtraction Assignment
a -= 5
print ("a -= 5 : ", a)
# Multiplication Assignment
a *= 5
print ("a *= 5 : ", a)
# Division Assignment
a /= 5
print ("a /= 5 : ",a)
# Remainder Assignment
a %= 3
print ("a %= 3 : ", a)
# Exponent Assignment
a **= 2
print ("a **= 2 : ", a)
# Floor Division Assignment
a //= 3
print ("a //= 3 : ", a)
# Out:
# a += 5 :  15
# a -= 5 :  10
# a *= 5 :  50
# a /= 5 :  10.0
# a %= 3 :  1.0
# a **= 2 :  1.0
# a //= 3 :  0.0

# %%
#identity operator it compares the memory loction. 
a=84
b=64
if a is b:
    print("both are same")
else:
    print("both are not same")
# Out:
# both are not same

# %%
#Logical operator.
num1 = int(input("Enter a number:"))
num2 = int(input("Enter one more number:"))
if num1>105 and num2<110:
    print("number is between 106 to 109")
elif (num1<110 or num2<90):
    print("three digit number")
else:
    print("nothing")
# Out:
# Enter a number: 263
# Enter one more number: 131
# nothing

# %% [raw]
# Q5.Explain the concept of of type casting in python with example.
#    python supports type casting due to this it can convert python data type in to certain data type.
#    There are two type of type casting
#        1.Implicit type conversion.
#        2.explicit type conversion.
#     >>Implicit type conversion-In implicit type conversion user don't need to convert data type.python                 automatically convert the datatype.
#     >>explicit type conversion-In this type of conversion user need to convert datatype.

# %%
#example of implicit type conversion
a=5
type(a)
# Out:
# int

# %%
b=1.5
type(b)
# Out:
# float

# %%
name = "amit"
type(name)
# Out:
# str

# %%
#### Example of explicit type conversion
num=input("Enter a number")
print(num)
type(num)
#here input is taken as str by python.
# Out:
# Enter a number 18
# 18
# str

# %%
#changing the 
num1 = int(num)
print(num1)
type(num1)
# Out:
# 18
# int

# %% [raw]
# Q6. How do conditional statement work in python? ellustrate with examples.
#     Conditional statements are the statements in python which are use to control flow of the program,with the use       of conditional statement we can restrict programms by giving certain condititons.
#     example

# %%
#example
if 10 % 2 == 0:
    print("even no")
else:
    print("odd")
# Out:
# even no

# %% [raw]
# Type of conditional statement:-
# if conditional statement
# if, else conditional statement
# if-elif-else conditional statement
# nested if-else conditional statement

# %%
#example of if-else conditional statement
your_salary_dollar = int(input("Enter your total salary:"))
if your_salary_dollar > 15000:
                         print("you are rich")
else:
    print("you are poor")
# Out:
# Enter your total salary: 250
# you are poor

# %%
#example of if-elif-else conditional statement
total_wealth_dollar = int(input("Enter your total wealth:"))
if (total_wealth_dollar > 100000):
    print("you are rich")
elif (25000 < total_wealth_dollar < 50000):
    print("Yor are from middle class family.")
else:
    print("you are poor")
# Out:
# Enter your total wealth: 546
# you are poor

# %% [raw]
# Q7.Describe the different types of loops and their use case with examples.
#     Loop is a programming instruction that repeate a sequence of instruction in program until some specific             condition met.
#     With the use looping we can reduce the rewriting of code which will helps us in many ways like saving time         ,space and many more.
#     ##There are two types of loop.
#     1.Entry control loop
#       a)for
#       b)while
#     2.Exit control loop
#      do-while loop

# %%
#example of for loop
for i in range(4):
    print( i , end= " ")
# Out:
# 0 1 2 3

# %%
#while loop example
n = 9
i = 4
while n>i:
    print( i,end =" ")
    i = i + 1
